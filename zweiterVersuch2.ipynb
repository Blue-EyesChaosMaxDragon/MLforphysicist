# %%
from google.colab import drive

drive.mount('/content/gdrive')
root_path1 = 'gdrive/My Drive/MLforphysicist'
root_path2 = 'gdrive/My\ Drive/MLforphysicist'  #change dir to your project folder
repo_path1 = root_path1+"/frcnn-from-scratch-with-keras"
repo_path2 = root_path2+"/frcnn-from-scratch-with-keras"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
requirement_path = repo_path2+"/requirements.txt"
print(requirement_path)
print(type(requirement_path))

# !pip install -r {requirement_path}
# !pip install tensorflow==1.15.0
# Out:
# gdrive/My\ Drive/MLforphysicist/frcnn-from-scratch-with-keras/requirements.txt
# <class 'str'>
# ...
#      |████████████████████████████████| 317kB 9.4MB/s
# ...
#   Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# ...
#      |████████████████████████████████| 412.3MB 39kB/s
# ...
#      |████████████████████████████████| 512kB 53.8MB/s
# ...
#      |████████████████████████████████| 3.8MB 49.7MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=e3cd6aab1a594df8e60e9075b2d08dd2f77356d706599783883cd5afe6777fb8
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.10.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ...
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
# ...

# %%
#import TF  
import tensorflow as tf
import keras
from platform import python_version
print("Tensorflow version", tf.__version__)
print("keras version", keras.__version__)
print("Python version =",python_version())
# Out:
# Tensorflow version 1.15.0
# keras version 2.2.4
# Python version = 3.6.9
# Using TensorFlow backend.

# %%
from tensorflow.python.client import device_lib

device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 6359078429296565828, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 852421054049942417
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 3584299792448809191
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14911763252
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 5186797407216823771
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"]

# %%
#python train_rpn.py --network vgg16 -o simple -p ./dataset.txt
train_path = repo_path2+"/train_rpn.py"
print(train_path)

data_path = root_path2+"/firsttrain.txt"
print(data_path)

hyper_path = root_path2+"/test2.json"
print(hyper_path)

input_weights = root_path2+"/weights/vgg16_weights_tf_dim_ordering_tf_kernels.h5"

# !python {train_path} -o simple -p {data_path} --input_weight_path {input_weights} --hyper {hyper_path}
# Out:
# gdrive/My\ Drive/MLforphysicist/frcnn-from-scratch-with-keras/train_rpn.py
# gdrive/My\ Drive/MLforphysicist/firsttrain.txt
# gdrive/My\ Drive/MLforphysicist/test2.json
# Using TensorFlow backend.
# WARNING:tensorflow:From gdrive/My Drive/MLforphysicist/frcnn-from-scratch-with-keras/train_rpn.py:29: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From gdrive/My Drive/MLforphysicist/frcnn-from-scratch-with-keras/train_rpn.py:31: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-07-13 06:56:42.585892: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2020-07-13 06:56:42.590678: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000170000 Hz
# ...

# %%
#python train_rpn.py --network vgg16 -o simple -p ./dataset.txt
train_path = repo_path2+"/train_frcnn.py"
print(train_path)

data_path = root_path2+"/firsttrain.txt"
print(data_path)

pre_rpn = root_path2+"/self_trained_model/test2/rpn.hdf5"
print(pre_rpn)

hyper_path = root_path2+"/test2.json"
print(hyper_path)

# !python {train_path} -o simple -p {data_path} --rpn {pre_rpn} --hyper {hyper_path}
# Out:
# gdrive/My\ Drive/MLforphysicist/frcnn-from-scratch-with-keras/train_frcnn.py
# gdrive/My\ Drive/MLforphysicist/firsttrain.txt
# gdrive/My\ Drive/MLforphysicist/self_trained_model/test2/rpn.hdf5
# gdrive/My\ Drive/MLforphysicist/test2.json
# Using TensorFlow backend.
# WARNING:tensorflow:From gdrive/My Drive/MLforphysicist/frcnn-from-scratch-with-keras/train_frcnn.py:24: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From gdrive/My Drive/MLforphysicist/frcnn-from-scratch-with-keras/train_frcnn.py:26: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-07-13 07:21:23.798568: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2020-07-13 07:21:23.803214: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000170000 Hz
# ...

# %%
# !ls

# %%
# !ls models/

# %%
# !ls models/vgg
