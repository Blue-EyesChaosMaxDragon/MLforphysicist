# %%
from google.colab import drive

drive.mount('/content/gdrive')
root_path1 = 'gdrive/My Drive/MLforphysicist'
root_path2 = 'gdrive/My\ Drive/MLforphysicist'  #change dir to your project folder
repo_path1 = root_path1+"/frcnn-from-scratch-with-keras"
repo_path2 = root_path2+"/frcnn-from-scratch-with-keras"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
requirement_path = repo_path2+"/requirements.txt"
print(requirement_path)
print(type(requirement_path))

# !pip install -r {requirement_path}
# !pip install tensorflow==1.15.0
# Out:
# gdrive/My\ Drive/MLforphysicist/frcnn-from-scratch-with-keras/requirements.txt
# <class 'str'>
# ...
#      |████████████████████████████████| 317kB 2.8MB/s
# ...
#   Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# ...
#      |████████████████████████████████| 412.3MB 23kB/s
# ...
#      |████████████████████████████████| 512kB 42.5MB/s
# ...
#      |████████████████████████████████| 3.8MB 42.7MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=f64696e808374a88cb76daea69d9439b8fb1c3405a1c927d11c8d93351367beb
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.10.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ...
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
# ...

# %%
#import TF  
import tensorflow as tf
import keras
from platform import python_version
print("Tensorflow version", tf.__version__)
print("keras version", keras.__version__)
print("Python version =",python_version())
# Out:
# Tensorflow version 1.15.0
# keras version 2.2.4
# Python version = 3.6.9
# Using TensorFlow backend.

# %%
from tensorflow.python.client import device_lib

device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 9040460397896300310, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 1762162169823168352
#  physical_device_desc: "device: XLA_CPU device"]

# %%
#python train_rpn.py --network vgg16 -o simple -p ./dataset.txt
test_path = repo_path2+"/test_frcnn.py"
print(test_path)

data_path = root_path2+"/test"
print(data_path)

#pre_rpn = root_path2+"/Pretrained_rpn_model/voc.hdf5"
#output_weights = root_path2+"/self_trained_model/first_model_frcnn.hdf5"
output_config = root_path2+"/self_trained_model/test/final_config.pickle"
load_model = root_path2+"/self_trained_model/test/final.hdf5"

# !python {test_path} --num_rois 15 --network vgg -p {data_path} --config_filename {output_config} --load {load_model}
# Out:
# gdrive/My\ Drive/MLforphysicist/frcnn-from-scratch-with-keras/test_frcnn.py
# gdrive/My\ Drive/MLforphysicist/test
# Using TensorFlow backend.
# 2020-07-12 23:06:29.300193: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-07-12 23:06:29.307770: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-07-12 23:06:29.308097: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2336bc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-07-12 23:06:29.308141: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-07-12 23:06:29.312550: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# ...
