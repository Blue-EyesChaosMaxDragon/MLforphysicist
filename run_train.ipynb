# %%
import pandas as pd
import numpy as np
import os
import pathlib

# %%
from google.colab import drive

drive.mount('/content/gdrive')
root_path = '/content/gdrive/My Drive/MLforphysicist'
root_path2 = '/content/gdrive/My\ Drive/MLforphysicist'

# %%
# Clone the tensorflow models repository if it doesn't already exist
if "models" in pathlib.Path.cwd().parts:
  while "models" in pathlib.Path.cwd().parts:
    os.chdir('..')
elif not pathlib.Path('models').exists():
  # !git clone --depth 1 https://github.com/Blue-EyesChaosMaxDragon/models

# %%
# Install the Object Detection API
# %%bash
cd models/research/
protoc object_detection/protos/*.proto --python_out=.
cp object_detection/packages/tf2/setup.py .
python -m pip install .

# %%
# train script must be run from the tensorflow/models/research/ directory
os.chdir('models/research')
# !ls

# %%
#setup directory, containing the config file and directory called train
# checkpoints containing the wegiths will be placed in main directory and event file in train
PIPELINE_CONFIG_PATH = root_path2+"/models/my_model_dir_detection_target/pipeline.config"
MODEL_DIR = root_path2+"/models/my_model_dir_detection_target"
num_train = 50 # sample_1_of_n_eval_on_train_example
num_eval = 50 # sample_1_of_n_eval_exampl

# %%
# running the train script from tensorflow/models/research/object_detection
train_file = "object_detection/model_main_tf2.py"

# !python {train_file} --pipeline_config_path={PIPELINE_CONFIG_PATH} --model_dir={MODEL_DIR} --eval_on_train_data=True -- sample_1_of_n_eval_examples={num_eval} --sample_1_of_n_eval_on_train_example={num_train} --alsologtostderr

# %%
#%reload_ext tensorboard
#%tensorboard --logdir=

# %%
#import os
#!ls models/research/object_detection/
#os.chdir('..')
#print(os.getcwd())

# %%
#!ls /content/models/research/object_detection/

# %%
#!tensorboard --logdir={MODEL_DIR}

# %%
# !ls #research/
